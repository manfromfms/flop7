# %%
from modules.Flip7_solver import solver_simple
from modules.Flip7_classes import Hand, Deck

# %%
hand = Hand.fromList([
    '+2',
    '11',
    '10',
    '2',
])
deck = Deck.SimpleDeck()

out = ['2', '7', '11', '11', '8', '10', '12', '6', '11', '5', '12', '4', '10', '6', '9', '4', '11', '6', '5', '+4', '9', '5', '10', '9', '10', '11', '+2', '11', '10', '2']
for o in out:
    deck.pop(o)

discard = Deck({
    '2': 1,
    '4': 2,
    '5': 3,
    '6': 3,
    '7': 1,
    '8': 1,
    '9': 3,
    '10': 4,
    '11': 5,
    '12': 2,
    '+4': 1
})

score = solver_simple(hand, deck, discard)

print(score)
# Out:
# info card 0 prob 0.01818181818181818 value 25 score 0.45454545454545453
# info card 1 prob 0.01818181818181818 value 26 score 0.4727272727272727
# info card 3 prob 0.05454545454545454 value 28 score 1.5272727272727273
# info card 4 prob 0.03636363636363636 value 29 score 1.0545454545454545
# info card 5 prob 0.03636363636363636 value 30 score 1.0909090909090908
# info card 6 prob 0.05454545454545454 value 31 score 1.690909090909091
# info card 7 prob 0.10909090909090909 value 32 score 3.4909090909090907
# info card 8 prob 0.12727272727272726 value 33 score 4.2
# info card 9 prob 0.10909090909090909 value 34 score 3.709090909090909
# info card 10 prob 0.09090909090909091 value 0.0 score 0.0
# info card 11 prob 0.09090909090909091 value 0.0 score 0.0
# info card 12 prob 0.18181818181818182 value 25 score 4.545454545454546
# info card +6 prob 0.01818181818181818 value 31 score 0.5636363636363636
# info card +8 prob 0.01818181818181818 value 33 score 0.6
# ...
